# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car=pd.read_csv('quikr_car.csv')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.shape
# Out:
# (892, 6)

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
car['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %% [markdown]
# ## QUALITY
#
# - year has many non-year values
# - year object to int
# - removing 'ask for price' entity
# - kms_driven has kms with integers
# - kms_driven to int
# - fuel type has nan values
# - keep first three words as name

# %% [markdown]
# CLEANING

# %%
backup=car.copy()

# %%
car[car['year'].str.isnumeric()]
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
import pandas as pd

car['year'] = pd.to_numeric(car['year'], errors='coerce')
car['year'] = car['year'].fillna(0).astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    int64
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 41.9+ KB

# %%
car[car['Price']!="Ask For Price"]
# Out:
#                                        name    company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  5,75,000
# 6                                 Ford Figo       Ford  2012  1,75,000
# ..                                      ...        ...   ...       ...
# 887                                      Ta       Tara     0  3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018  2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013  3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 3    28,000 kms    Petrol
# ...

# %%
import pandas as pd

car['Price'] = car['Price'].str.replace(',', '', regex=False)
car['Price'] = pd.to_numeric(car['Price'], errors='coerce')

# %%
car['Price']
# Out:
# 0       80000.0
# 1      425000.0
# 2           NaN
# 3      325000.0
# 4      575000.0
#          ...
# 887    310000.0
# 888    260000.0
# 889    390000.0
# 890    180000.0
# 891    160000.0
# Name: Price, Length: 892, dtype: float64

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0).str.replace(',',' ')

# %%
car = car[car['kms_driven'].fillna('').astype(str).str.isnumeric()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 1 to 763
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        19 non-null     object
#  1   company     19 non-null     object
#  2   year        19 non-null     int64
#  3   Price       17 non-null     float64
#  4   kms_driven  19 non-null     object
#  5   fuel_type   19 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.0+ KB

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 1 to 763
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        19 non-null     object
#  1   company     19 non-null     object
#  2   year        19 non-null     int64
#  3   Price       17 non-null     float64
#  4   kms_driven  19 non-null     int64
#  5   fuel_type   19 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.0+ KB

# %%
car[~car['fuel_type'].isna()]
# Out:
#                                        name   company  year      Price  \
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006   425000.0
# 15                  Mahindra Jeep CL550 MDI  Mahindra  2006   425000.0
# 215                Mahindra Jeep MM 550 XDB  Mahindra  2019   390000.0
# 222                 Mahindra Jeep CL550 MDI  Mahindra  2018   385000.0
# 302   Maruti Suzuki Swift VXi 1.2 ABS BS IV    Maruti  2019   610000.0
# 364                Mahindra Jeep MM 550 XDB  Mahindra  2019   390000.0
# 381                 Mahindra Jeep CL550 MDI  Mahindra  2018   385000.0
# 382                Mahindra Jeep MM 550 XDB  Mahindra  2006   425000.0
# 387      Toyota Innova 2.5 E MS 7 STR BS IV    Toyota  2012   770000.0
# 427           Nissan X Trail Select Variant    Nissan  2019  1200000.0
# 470      Maruti Suzuki Swift Dzire Tour VXi    Maruti  2011   230000.0
# 485                  Tata Tigor Revotron XZ      Tata  2019   650000.0
# ...

# %%
car['name']=car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car=car.reset_index(drop=True)

# %%
car
# Out:
#                    name   company  year      Price  kms_driven fuel_type
# 0   Mahindra Jeep CL550  Mahindra  2006   425000.0          40    Diesel
# 1   Mahindra Jeep CL550  Mahindra  2006   425000.0          40    Diesel
# 2      Mahindra Jeep MM  Mahindra  2019   390000.0          60    Diesel
# 3   Mahindra Jeep CL550  Mahindra  2018   385000.0         588    Diesel
# 4   Maruti Suzuki Swift    Maruti  2019   610000.0          73    Petrol
# 5      Mahindra Jeep MM  Mahindra  2019   390000.0          60    Diesel
# 6   Mahindra Jeep CL550  Mahindra  2018   385000.0         588    Diesel
# 7      Mahindra Jeep MM  Mahindra  2006   425000.0         122    Diesel
# 8     Toyota Innova 2.5    Toyota  2012   770000.0           0    Diesel
# 9        Nissan X Trail    Nissan  2019  1200000.0         300    Diesel
# 10  Maruti Suzuki Swift    Maruti  2011   230000.0          65    Petrol
# 11  Tata Tigor Revotron      Tata  2019   650000.0         100    Diesel
# ...

# %%
car['Price'].fillna(car['Price'].median(), inplace=True)
# Out:
# C:\Users\NEEL\AppData\Local\Temp\ipykernel_10908\1028622736.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Price'].fillna(car['Price'].median(), inplace=True)

# %%
car
# Out:
#                    name   company  year      Price  kms_driven fuel_type
# 0   Mahindra Jeep CL550  Mahindra  2006   425000.0          40    Diesel
# 1   Mahindra Jeep CL550  Mahindra  2006   425000.0          40    Diesel
# 2      Mahindra Jeep MM  Mahindra  2019   390000.0          60    Diesel
# 3   Mahindra Jeep CL550  Mahindra  2018   385000.0         588    Diesel
# 4   Maruti Suzuki Swift    Maruti  2019   610000.0          73    Petrol
# 5      Mahindra Jeep MM  Mahindra  2019   390000.0          60    Diesel
# 6   Mahindra Jeep CL550  Mahindra  2018   385000.0         588    Diesel
# 7      Mahindra Jeep MM  Mahindra  2006   425000.0         122    Diesel
# 8     Toyota Innova 2.5    Toyota  2012   770000.0           0    Diesel
# 9        Nissan X Trail    Nissan  2019  1200000.0         300    Diesel
# 10  Maruti Suzuki Swift    Maruti  2011   230000.0          65    Petrol
# 11  Tata Tigor Revotron      Tata  2019   650000.0         100    Diesel
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        19 non-null     object
#  1   company     19 non-null     object
#  2   year        19 non-null     int64
#  3   Price       19 non-null     float64
#  4   kms_driven  19 non-null     int64
#  5   fuel_type   19 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.0+ KB

# %%
car = car.astype({
    'year': 'int32',
    'Price': 'int32',
    'kms_driven': 'int32'
})

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        19 non-null     object
#  1   company     19 non-null     object
#  2   year        19 non-null     int32
#  3   Price       19 non-null     int32
#  4   kms_driven  19 non-null     int32
#  5   fuel_type   19 non-null     object
# dtypes: int32(3), object(3)
# memory usage: 816.0+ bytes

# %%
car.describe()
# Out:
#               year         Price  kms_driven
# count    19.000000  1.900000e+01   19.000000
# mean   2014.578947  5.251316e+05  127.578947
# std       5.699082  2.767764e+05  192.034232
# min    2004.000000  1.250000e+05    0.000000
# 25%    2010.000000  3.900000e+05    0.000000
# 50%    2018.000000  4.250000e+05   60.000000
# 75%    2019.000000  5.892500e+05  111.000000
# max    2019.000000  1.200000e+06  588.000000

# %%
car[car['Price']<6e6].reset_index(drop=True)
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 0   Mahindra Jeep CL550  Mahindra  2006   425000          40    Diesel
# 1   Mahindra Jeep CL550  Mahindra  2006   425000          40    Diesel
# 2      Mahindra Jeep MM  Mahindra  2019   390000          60    Diesel
# 3   Mahindra Jeep CL550  Mahindra  2018   385000         588    Diesel
# 4   Maruti Suzuki Swift    Maruti  2019   610000          73    Petrol
# 5      Mahindra Jeep MM  Mahindra  2019   390000          60    Diesel
# 6   Mahindra Jeep CL550  Mahindra  2018   385000         588    Diesel
# 7      Mahindra Jeep MM  Mahindra  2006   425000         122    Diesel
# 8     Toyota Innova 2.5    Toyota  2012   770000           0    Diesel
# 9        Nissan X Trail    Nissan  2019  1200000         300    Diesel
# 10  Maruti Suzuki Swift    Maruti  2011   230000          65    Petrol
# 11  Tata Tigor Revotron      Tata  2019   650000         100    Diesel
# ...

# %%
car
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 0   Mahindra Jeep CL550  Mahindra  2006   425000          40    Diesel
# 1   Mahindra Jeep CL550  Mahindra  2006   425000          40    Diesel
# 2      Mahindra Jeep MM  Mahindra  2019   390000          60    Diesel
# 3   Mahindra Jeep CL550  Mahindra  2018   385000         588    Diesel
# 4   Maruti Suzuki Swift    Maruti  2019   610000          73    Petrol
# 5      Mahindra Jeep MM  Mahindra  2019   390000          60    Diesel
# 6   Mahindra Jeep CL550  Mahindra  2018   385000         588    Diesel
# 7      Mahindra Jeep MM  Mahindra  2006   425000         122    Diesel
# 8     Toyota Innova 2.5    Toyota  2012   770000           0    Diesel
# 9        Nissan X Trail    Nissan  2019  1200000         300    Diesel
# 10  Maruti Suzuki Swift    Maruti  2011   230000          65    Petrol
# 11  Tata Tigor Revotron      Tata  2019   650000         100    Diesel
# ...

# %%
car['Price'].describe()
# Out:
# count    1.900000e+01
# mean     5.251316e+05
# std      2.767764e+05
# min      1.250000e+05
# 25%      3.900000e+05
# 50%      4.250000e+05
# 75%      5.892500e+05
# max      1.200000e+06
# Name: Price, dtype: float64

# %%
car['Price'].max()
# Out:
# np.int32(1200000)

# %%
car = car[car['Price'] < 600000].reset_index(drop=True)

# %%
len(car[car['Price'] >= 600000])
# Out:
# 0

# %%
car['Price'].dtype
# Out:
# dtype('int32')

# %%
car = (car.assign(Price=pd.to_numeric(car['Price'].astype(str)
                                      .str.replace(',', '')
                                      .str.strip(),
                                      errors='coerce'))
          .query('Price < 600000')
          .reset_index(drop=True))

# %%
car['Price'].max()
len(car)
# Out:
# 14

# %%
car = car[car['Price'] < 600000].reset_index(drop=True)

# %%
car
# Out:
#                    name   company  year   Price  kms_driven fuel_type
# 0   Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 1   Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      Mahindra Jeep MM  Mahindra  2019  390000          60    Diesel
# 3   Mahindra Jeep CL550  Mahindra  2018  385000         588    Diesel
# 4      Mahindra Jeep MM  Mahindra  2019  390000          60    Diesel
# 5   Mahindra Jeep CL550  Mahindra  2018  385000         588    Diesel
# 6      Mahindra Jeep MM  Mahindra  2006  425000         122    Diesel
# 7   Maruti Suzuki Swift    Maruti  2011  230000          65    Petrol
# 8        Datsun Go Plus    Datsun  2016  425000           5    Petrol
# 9      Mahindra Jeep MM  Mahindra  2004  424000         383    Diesel
# 10     Ford Figo Petrol      Ford  2019  525000           0    Petrol
# 11    Maruti Suzuki Zen    Maruti  2009  125000           0    Petrol
# ...

# %%
car.to_csv('Cleaned Car.csv')

# %% [markdown]
# MODEL

# %%
X=car.drop(columns='Price')
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Datsun Go Plus', 'Ford Figo Petrol', 'Mahindra Jeep CL550',
#         'Mahindra Jeep MM', 'Maruti Suzuki Swift', 'Maruti Suzuki Zen',
#         'Tata Nexon', 'Tata Tiago Revotorq'], dtype=object),
#  array(['Datsun', 'Ford', 'Mahindra', 'Maruti', 'Tata'], dtype=object),
#  array(['Diesel', 'Petrol'], dtype=object)]

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Datsun Go Plus', 'Ford Figo Petrol', 'Mahindra Jeep CL550',
#        'Mahindra Jeep MM', 'Maruti Suzuki Swift', 'Maruti Suzuki Zen',
#        'Tata Nexon', 'Tata Tiago Revotorq'], dtype=object),
#                                                                             array(['Datsun', 'Ford', 'Mahindra', 'Maruti', 'Tata'], dtype=object),
#                                                                             array(['Diesel', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
y_pred
# Out:
# array([384661.27845139, 390438.08953866, 395643.29472387])

# %%
r2_score(y_test,y_pred)
# Out:
# -0.36729599281496084

# %%
scores=[]
for i in range(10):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    print(r2_score(y_test,y_pred),i)
    scores.append(r2_score(y_test,y_pred))
# Out:
# -0.5677196413563643 0
# 0.9396247406294183 1
# 0.0021471705043550893 2
# 0.9407138900249955 3
# 0.0021471703844689882 4
# 0.9395532790443797 5
# -2.8303051891572824 6
# 0.3310728344110877 7
# 0.3601416356666286 8
# 0.3885639823980045 9

# %%
np.argmax(scores)
# Out:
# np.int64(3)

# %%
scores[np.argmax(scores)]
# Out:
# 0.9407138900249955

# %%
 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
 lr=LinearRegression()
 pipe=make_pipeline(column_trans,lr)
 pipe.fit(X_train,y_train)
 y_pred=pipe.predict(X_test)
 r2_score(y_test,y_pred)
# Out:
# 0.9407138900249955

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Dzire','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 pipe.predict(pd.DataFrame([['Maruti Suzuki Dzire','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786 if not _routing_enabled():
#     787     for _, name, transform in self._iter(with_final=False):
# --> 788         Xt = transform.transform(Xt)
#     789     return self.steps[-1][1].predict(Xt, **params)
#     791 # metadata routing enabled
#
# ...
